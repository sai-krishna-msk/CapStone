# %%
file = "os_comp.txt"

# %%
with open(file, encoding="utf8") as f:
    corpus = f.read()

# %%
corpus.replace("  ", "").replace("\n", "").split(" ")
# Out:
# ['an',
#  'operating',
#  'system',
#  'acts',
#  'as',
#  'an',
#  'intermediary',
#  'between',
#  'the',
#  'user',
#  'of',
#  'a',
#  'computer',
#  'and',
#  'computer',
#  'hardware.',
#  'the',
#  'purpose',
#  'of',
#  'an',
#  'operating',
#  'system',
#  'is',
#  'to',
#  'provide',
#  'an',
#  'environment',
#  'in',
#  'which',
#  'a',
#  'user',
#  'can',
#  'execute',
#  'programs',
#  'in',
#  'a',
#  'convenient',
#  'and',
#  'efficient',
#  'manner.an',
#  'operating',
#  'system',
#  'is',
#  'a',
#  'software',
#  'that',
#  'manages',
#  'the',
#  'computer',
#  'hardware.',
#  'the',
#  'hardware',
#  'must',
#  'provide',
#  'appropriate',
#  'mechanisms',
#  'to',
#  'ensure',
#  'the',
#  'correct',
#  'operation',
#  'of',
#  'the',
#  'computer',
#  'system',
#  'and',
#  'to',
#  'prevent',
#  'user',
#  'programs',
#  'from',
#  'interfering',
#  'with',
#  'the',
#  'proper',
#  'operation',
#  'of',
#  'the',
#  'system.operating',
#  'system',
# ...
